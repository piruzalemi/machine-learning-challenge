# %%
from sklearn import tree
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.join("exoplanet_data.csv"))
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
target = df["koi_disposition"]
target_names = ["negative", "positive"]

# %%
data = df.drop("koi_disposition", axis=1)
feature_names = data.columns
data.head()
# Out:
#    koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0              0              0              0              0   54.418383
# 1              0              1              0              0   19.899140
# 2              0              1              0              0    1.736952
# 3              0              0              0              0    2.525592
# 4              0              0              0              0    4.134435
#
#    koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0     2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1     1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2     2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3     3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4     1.050000e-05    -1.050000e-05   172.979370          0.001900
#
#    koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0         -0.003520  ...             -81      4.467           0.064
# 1         -0.000581  ...            -176      4.544           0.044
# 2         -0.000115  ...            -174      4.564           0.053
# 3         -0.001130  ...            -211      4.438           0.070
# 4         -0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 40 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.847254004576659

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=20)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.8872997711670481

# %%
rf_pred = rf.predict(X_test)

# %%
rf_pred[:20]
# Out:
# array(['FALSE POSITIVE', 'CANDIDATE', 'FALSE POSITIVE', 'FALSE POSITIVE',
#        'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE', 'CANDIDATE',
#        'CANDIDATE', 'FALSE POSITIVE', 'CONFIRMED', 'CONFIRMED',
#        'CONFIRMED', 'FALSE POSITIVE', 'CANDIDATE', 'CANDIDATE',
#        'FALSE POSITIVE', 'FALSE POSITIVE', 'CONFIRMED', 'CANDIDATE'],
#       dtype=object)

# %%
X_test[:20]
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4982              1              0              0              0   88.523517
# 4866              0              0              0              0  102.493119
# 2934              0              0              1              0    1.181165
# 5007              0              1              0              0    8.412009
# 3869              0              1              1              1    1.195515
# 233               0              0              0              0    5.826658
# 1554              0              0              0              0    3.032671
# 6156              0              0              0              0  240.192808
# 4874              0              0              0              0  104.198102
# 4844              1              0              0              0  502.658000
# 2471              0              0              0              0   24.674582
# 2398              0              0              0              0   29.007892
# 239               0              0              0              0    4.942783
# 5681              0              1              0              0    2.025580
# 4701              0              0              0              0  583.853100
# 5706              0              0              0              0    1.966828
# 3617              0              1              1              1    0.905676
# 5982              1              0              0              0    2.344139
# 1426              0              0              0              0    3.788618
# 3614              0              0              0              0   54.649368
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4982     2.337000e-03    -2.337000e-03   189.275600          0.023200
# 4866     1.322000e-03    -1.322000e-03   166.009400          0.010500
# 2934     3.890000e-06    -3.890000e-06   132.425220          0.002760
# 5007     2.360000e-07    -2.360000e-07   139.648520          0.000024
# 3869     5.730000e-07    -5.730000e-07   132.303851          0.000410
# 233      6.430000e-06    -6.430000e-06   173.011411          0.000925
# 1554     1.370000e-05    -1.370000e-05   134.066800          0.003810
# 6156     8.989000e-03    -8.989000e-03   168.304700          0.030700
# 4874     1.140000e-03    -1.140000e-03   161.446900          0.010300
# 4844     3.868000e-02    -3.868000e-02   174.629400          0.034500
# 2471     8.150000e-05    -8.150000e-05   146.772610          0.002510
# 2398     8.480000e-05    -8.480000e-05   170.553490          0.002050
# 239      2.470000e-07    -2.470000e-07   136.329435          0.000041
# 5681     2.710000e-07    -2.710000e-07   131.864175          0.000111
# 4701     1.404000e-02    -1.404000e-02   362.141600          0.020900
# 5706     2.150000e-05    -2.150000e-05   132.686320          0.008710
# 3617     9.010000e-06    -9.010000e-06   132.200660          0.008460
# 5982     7.180000e-06    -7.180000e-06   131.575890          0.002580
# 1426     2.290000e-05    -2.290000e-05   134.614190          0.004970
# 3614     9.710000e-04    -9.710000e-04   176.044700          0.016400
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
#
# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.1136053031144643, 'koi_fpflag_co'),
#  (0.10640702576574661, 'koi_fpflag_nt'),
#  (0.06855413121390044, 'koi_prad'),
#  (0.06651264742114947, 'koi_model_snr'),
#  (0.04749441320981477, 'koi_fpflag_ss'),
#  (0.032981567448639254, 'koi_prad_err1'),
#  (0.030837362259726248, 'koi_duration_err1'),
#  (0.03070324533024274, 'koi_time0bk_err1'),
#  (0.029432199652770885, 'koi_duration_err2'),
#  (0.029127598120574017, 'koi_insol_err1'),
#  (0.028230160691712164, 'koi_prad_err2'),
#  (0.025271484378611514, 'koi_steff_err2'),
#  (0.024495960633220397, 'koi_fpflag_ec'),
#  (0.02404188097057974, 'koi_steff_err1'),
#  (0.02190213355327451, 'koi_impact'),
#  (0.02166601117308672, 'koi_duration'),
#  (0.021039669799375084, 'koi_depth'),
#  (0.019926638664462048, 'koi_period'),
#  (0.017997738785807533, 'koi_period_err1'),
#  (0.017734780243394276, 'koi_period_err2'),
#  (0.015636269850481672, 'koi_depth_err2'),
#  (0.015285895879923527, 'koi_insol'),
#  (0.014987572933373952, 'koi_time0bk_err2'),
#  (0.01403073682590921, 'koi_time0bk'),
#  (0.013410440917453064, 'koi_insol_err2'),
#  (0.01302010362738141, 'koi_depth_err1'),
#  (0.012336901841366363, 'dec'),
#  (0.01203582203574841, 'ra'),
#  (0.011673899365982765, 'koi_srad_err1'),
#  (0.011192223860060867, 'koi_impact_err2'),
#  (0.010995879166217856, 'koi_impact_err1'),
#  (0.010847474464632568, 'koi_teq'),
#  (0.010179985349623178, 'koi_kepmag'),
#  (0.009566256884665605, 'koi_steff'),
#  (0.009219297017685226, 'koi_slogg'),
#  (0.009206893669885117, 'koi_slogg_err2'),
#  (0.008674943581396298, 'koi_srad'),
#  (0.008295444139882733, 'koi_slogg_err1'),
#  (0.008029449737119628, 'koi_srad_err2'),
#  (0.003412556420657878, 'koi_tce_plnt_num')]

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(classification_report(y_test,rf_pred))
# Out:
#                 precision    recall  f1-score   support
#
#      CANDIDATE       0.79      0.76      0.78       411
#      CONFIRMED       0.83      0.81      0.82       484
# FALSE POSITIVE       0.96      0.99      0.97       853
#
#       accuracy                           0.89      1748
#      macro avg       0.86      0.85      0.86      1748
#   weighted avg       0.88      0.89      0.89      1748

# %%
print(confusion_matrix(y_test,rf_pred))
# Out:
# [[313  76  22]
#  [ 77 393  14]
#  [  4   4 845]]

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC
clf=SVC
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-660cfe473376> in <module>
#       2 from sklearn.svm import SVC
#       3 clf=SVC
# ----> 4 clf.fit(X_train, y_train)
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d1fec249e2f2> in <module>
#       2 from sklearn.svm import SVC
#       3 model = SVC
# ----> 4 model.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined
